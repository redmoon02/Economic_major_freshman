# %% [markdown]
# # 미시경제학의 기초
# ---
#
# - 미시경제학과 거시경제학, 그리고 하이에크
# - 희소성과 경제학
# - 모형
# - 가격기구
# - 암묵적 간주
# - 새뮤얼슨

# %% [markdown]
# ## 미시경제학과 거시경제학, 그리고 하이에크
# ---
#
# 경제라는 대상은 너무 드넓다 사회라는 대상을 , 인간을 무엇이다라고 말하는 것을 우리는 view로 여겨지는 것들에 대해서 먼저 이해해야한다. 역동하는 사람. 일단 그것을 역동한다고 보는 것 자체와 함께, 우리에게 있어, 경제학에서 위에서 아래로 보는 조망하는 방법에 대해서 거시경제학의 출발점이 되었던 사고였다. 반해 하이에크는 비용과 가치등 경제를 구성하는 다양한 요소에 주목하기 시작했고 우리는 현재 이를 미시경제적 사고라고 불리는 것들이 되었다.
#
# 케인즈의 `고용, 이자 ,화폐에 관한 일반이론`이  출간되기도 전에 치열하게 오갔던 케인스와 하이에크의 논쟁이 별소득 없이 끝나고, 결국 경제적 세계를 바라보는 서로 절충 불가능 한 두 입장의 충돌하는 모습은 1931년에 용어 정의의 세계로 이동되었다.
#
# 케인즈가 인간성을 희망적으로 바라보는 관점을 제시하고 이해했다면 , 하이에크는 회으론자이며 비관론자였다. 하이에크의 논지는 세상을 더 좋게 만드려고 애쓰는 사람들은 종국적으로 뜻하지 않는 결과를 부르기 쉽다고 생각했다.
# 자유시장은 개인의 자기 잇속에 바탕을 둔 합리적 결정을 준거로 삼을 때 가장 효과적으로 작동하며 , 이상주의자가 끼어들면 제대로 작동하지 못한다고 하였다. 낙관론과 이상론과는 다르게 비관론자인 하이에크는 현실세계를 바라볼 냉정한 길잡이를 찾았다.
#
# 케인즈는 이와 함께 실업문제의 해결을 위한 정부개입의 주장을 지속하였고 , 정부의 경제적 작동에 대해서 최악의상황을 해결하자는 노력을 했으며, 인간의 스스로의 운명을 결정할 수 있다는 생각을 기준으로했다. 시장의 큰 힘을 인간이 개입하면 부작용 만 난다는 주장의 하이에크는 경제 작동 방식에 대한 인간의 이해 자체가 어렵다고 생각했고 , 인간의 능력에 대한 회의를 비추었다.
#
# 케인즈는 1962년에 자유방임 종언 이라는 강연 (The End of Laissez-Faire) 에서 모든 개인의 개별적 자기 잇속을 합한 것이 공익 이라는 기존 경제학자들의 주장을 배격하고 , 정부의 적극적인 개입을 주장하며 경제학자에게 사회주의자라는 꼬리표를 얻었지만, 정치적으로 자유당에 오랜기간 몸담았고, 중도를 지향한 바 있었다.
#
# 경제학을 공부하며 LSE 런던정치경제대학을 빼고 말하긴 어렵지만 하이에크와 로빈스의 관계를 뒤로하고도 하이에크의 케인즈의 일반이론에 대한 반박을 이루지 못한 점은 아쉽게 여기는 부분이다. 거의 무반응으로 여거진 기간동안의 조용한 활동에 이어 하이에크는 1940년에 순수 자본 이론을 내놓았지만 , 경제하계에 큰 영향을 미치지 못하였지만 1944년  노예의길 (the Road of sefdom) 이 그의 시작으로 봐야할 것이다.
#
# 이 책에서 하이에크는 경제를 계획하는 사람이 시장의 자유로운 작동을 어떤 수준 이상으로 가로막기 시작하면 모든 문제에 간섭할 때까지 그의 통제력이 확장될 수밖에 없다고 주장했다. 경제 계획의 옮음과 유용함에 의의를 제기하는 대표적인 저술이되었다.
#
# 이후 하이에크의 미시경제적 시작보다는 거시경제적 시장개입이 케인즈주의와 함께 시장을 휩쓸고 이에 사장하는 지경에 이르르며 성장하던 도중 , 30년 번영기간의 끝으로 미국의 경제물가 상승과 실업이 동시에 출현하는 스태그 인플레이션을 만나 케인즈 주의 또한 종말을 맞았다. 이떄 부터 다시 하이에크가 다시 명성을 얻고 1974년 그는 노벨 경제학상을 수상하며 프리드먼의 통화주의가 설득력을 얻고 , 대처와 레이건은 하이에크의 사상을 내세웠다,
#
# 다시 자유시장이 대체로 , 공산주의 실험이 막을 내리며 1974년 몽펠르랭 정상회의에서 몽펠르랭 소사이어티의 시작 즉 자유주의 경제학자의 모임이 시작되었다.
#
# 그러나 당연히 그러하듯 이후에 거시경제학자중에 케인스주의자라고 밝히는 사람을 구경하기가 힘들어진 부분이 생긴 적도있다. 2007년 서브프라임 모기지 사태와 함께, 규제를 가하지 않은 시장이 터졌고, 다시 케인즈에게 귀를 기울이게 되었고, 이는 이 두사고의 옮음과 그름 자체를 논의하기 어려워 두 방식으로 나뉘게 되었고, 이로 우리는 미시경제학과 거시경제학으로 분리되어 보게 되었다.
#
# 2023년 현재에서 보는 현재의 경제상황은 IT붐을 넘어 4차 산업혁명과, 콘텐츠 산업과 환경, 지속가능성까지 결부되어 더욱이 복지까지 결합된 정책과 경제 그리고 가격결정에서 살아가고 있다. 코로나 이후와 이전의 변화는 경제 이전의 문화와 인간들의 관계에서 조차 다르며 이를 한국에서는 재난지원금이라는 명목으로 인당 화폐를 지급하고 지자체별로 지급함을 통해 시장에 어떤 결과를 가져왔는가 ? 에 대한 분석을 미시경제학에서는 처한 시대의 상황에 따라 인간의 능력에 대한 평가에 따라 이리저리 선택할수 있음에도 불구하고, 우리는 하이에크의 정신 중 하나인 맞닦드린 처지를 이해하고 거기서 비롯된 해결책을 제시하는 것이 우리가 배울 정신이다.
#
# 케인즈는 직감과 주먹구구식 계산에 의존하는 인간의 본성과 함께 유연성을 갖추었고, 하이에크는 그주장 이 극단적이라고도 느껴질지 모르지만 노예의 길에서 밝히듯 시대를 논하는 글이라고 묘사함에서 보이는 것처럼 특수한 조건을 의식하고 고려했다는 점을 이해할수 있을 것이다.
#
# 우리는 미시경제적 믿음이라고 볼 수 있는 이 하이에크의 믿음으로 인간의 능력과 본성에 관한 부분에 있어 미시경제학의 눈으로 볼 것이므로 우리가 다룰 주제는 바로 이 인간의 능력, 본성 그리고 선택들의 전개를 다룰 것이다.
#
#
# 좀더 깊은 논의는 미래에 미시경제학의 역사적 발전 그리고 학파별 토론을 통해 좀더 미제스의 이야기와 하이에크의 자유와 평등의 양립불가능성을 이해하고 추후에 nomos와 thesis 로 말하는 행위 준칙에 대한 이해로 고 학년에서 정립할 수 있을 것이다.
#
# 토론: 미시경제학과 거시경제학의 차이는 무엇이고 그렇다면 이에 따르면 미시와 거시가 포함하지 못하는  " 대상" 은 경제학적으로 존재하는가 ?

# %% [markdown]
# ## 희소성과 경제학
# ---
# 사람들의 욕심은 끊이 없고 자원은 한정적이다. 자원은 모든 자원들을 포함한다. 현재 공부를 한다면 하루에 24시간을 공부에만 사용할 수는 없을 것이다. 분명 이 시간을 공부에 사용하기 위해 다른 것에 사용할 시간이 준다는 것은 변하지 않는다.
# 결국 모든 자원이 희소하기 때문에 경제학은 가계 및 기업과 같은 개별 경제주체와 경제주체들의 모임인 경제 전체가 희소성의 문제를 어떻게 해결해야할 것인지를 분석하는 학문이다.
#
# 위에서 하이에크에 대해 말한 것처럼 미시경제학은 개별경제주체가 희소성의 문제를 어떻게 해결하는지 분석하는 학문이다.
# 미시경제학의 분석대상이 개별 경제 주체의 의사결정에만 국한되는 것이 아니라, 개별 경제주체들의 행위가 서로 결합되어 경제 전체에 어떠한 영향을 주는지도 포함한다.
# 거시경제학은 개별 경제주체의 행위가 아닌 경제전체의 현상이 주로 분석됨에 따라 국민소득, 물가, 실업  및 경기변동등과 같은 총량변수들이 분석된다. 최근에는 거시경제학에서도 미시경제적 분석의 중요성이 강조되면서 이를 micro foundations of macroeconomics라고 한다.
#
# 자원의 희소성으로 어떤 경제라도 생산물의 종류 및 생산량의 결정, 생산방법의 결정, 생산물의 분배라는 세가지 문재를 해결해야한다.
#
# 1. 생살물의 종류 및 생산량의 결정
# 자원이 희소하므로 어떤 재화의 생산량을 증사시킨다는 것은 다른 재화의 생산량을 감소시킴을 의미한다. 따라서 경제는 한정된 자원을 이용해 옷 주택 등의 다양한 재화들을 얼마큼 생산할 것인지 결정해야한다. 의사결정의 기준이되므로 우리는 이것을 경제학의 중심인 기회비용(opportunity cost) 라고 한다.
#
# 2. 생산방법의 결정
# 어떤 재화를 얼마만큼 생산할 것인지 결정되면, 어떠한 방법으로 그 재화를 생산할 것인지 결정한다. 생산요소들을 어떻게 투입하느냐의 효율성 달성하는 문제이다.
#
# 3. 생산물의 분배
# 자원이 희소하므로 모든 사람들이 재화를 원하는 만큼 가질 수 는 없다. 따라서 경제는 생산물을 사람들에게 분배하는 기구(mechanism)가 있어야하며, 설정된 기구에 의해 생산물의 분배는 공정해야한다.
#
# 위의 문제들은 경제체제에 따라 다르다. 사회주의 경제의 자원배분은 중앙정부의 계획애 의해이루어지며, 자본주의 경제의 자원배분은 시장기구 (market)에 의해 이루어진다. 시장은 가계와 기업의 독립적인 의사결정에 의해 자원배분이 이루어질 수 있도록 해주는 조직(organization)이다.
# 시장기구에 의해 자원배분이 이루어진다는 것은 가게와 기업이 각각 독립적으로 결정하는 시장 수요와 시장공급에 의해 자원배분이 이루어진다고 생각한다.
#
# 자본주의 경제에서는 자원배분이 시장에 의해 이루어지므로 시장기구의 원리와 자원배분의 평가를 보도록한다.
# 시장기구에 의한 자원배분은 결국 가격을 매개로 하여 이루어 지므로 자번주의 경제는 자원 배분이 가격기구 (price mechanism)에 의해 이루어진다고 말한다. 미시경제학에서는 이를 가격이라고 하며 가격론(price theory)
# 라고 부르기도 한다.

# %% [markdown]
# ## 모형
# 경제는 수많은 재화와 생산오소 다수의 가계와 기업들의 독립적인 의사결정을 이룬다. 복잡한 현실을 일일히 다 설명할 수 있는가? 그럴필요도 없으며 그 의미도 없다. 우리는 복잡한 현실속에서 essence만 을 파악해 분석하는 것이다.
# 중요성을가지지 않는 것들을 제외하고 보기위해서 우리는 이를 model를 사용하여 본다. 예를 들어 우리는 목적지를 가기위해서는 지도를 사용하나 지도에 등고선부터 세세한 지방도 까지 필요로하지 않다. 경제학에서사용하는 모형은 서술적일수도 있고 경우에 다라 수식이나 그림을 포함하기도한다.
#
# 모형은 설명 목적에 맞게 현실을 단순화 시키며 단순화가 아무기준 없이 이루어지는것이 아니기에, 좋은 이론이 되기위해서는 몇개의 주요 요인만을 포함하는 모형에 의해 대부분 혹은 다수의 다양한 관찰결과를 설명할 수 있어야하고 그로 미래 관찰결과가 정확히 예측되어야한다.
#
# 경제학에는 가장 단순화하여 이해하는 것으로 수입, 한계수입, 비용, 한계 비용, 이윤의 개념이 있다.
# 가장 단순하게는 이윤= 수입 - 비용 의 관게에 의해 계산할 수 있다.
# 한 단위 증가시에 얼마나 증가하느냐의 개념으로 한게라는 Marginal이라는 개념으로 우리는 cost와 revenue혹은 benefit을 가지고 한 단위의 개념을 가지고 MR, MC라는 용어로 사용하게 된다.
# 즉 MR > MC의 관계이면 이윤을 증가 시킬 수 있으므로 한계 이익이 한계 비용보다 크므로 이윤을 증가 시킬 수 있으므로 우리는 이때  MR = MC 인 그 지점에서 우리는 적정하게 결정된다고 볼수 있고 이를 최적의 결정이라고 생각할수 있다.
#
# 편익인 benefit을 생각해보자, 의사결정읠 하는 경제주체에게 이득이 되는 것을 말한다. 수입이 곧 편익이 되는 상황에서는 우리의 한계 비용과 한계 비용이 일치하는 지점의 적정은 MB = MC 이다.
# 즉 현재 교육 그리고 지금 이 시간을 이 글을 읽고 공부하고 혹은 책을 보면서 교육을 받는데 소비하는 시간을 들이는 cost 만큼 장래 수익인 benefit이 얼마나 느는지에 대해서 교육 연수를 정하는 것이 좋다. 수많은 고시준비생들의 10년 장기 투자가 그만큼의 의미가 있지만 30년동안 공시를 준비하는 사람은 없다. 인간은 항상 최적의 결정을 위해 그들만의 한계의 개념이 존재한다.

# %%
import matplotlib.pyplot as plt
import numpy as np

def marginal_cost(q):
    return 2 + 0.5*q

def marginal_revenue(q):
    return 10 - 0.5*q

q_values = np.arange(0, 20, 0.1)
mc_values = marginal_cost(q_values)
mr_values = marginal_revenue(q_values)

plt.plot(q_values, mc_values, label='Marginal Cost')
plt.plot(q_values, mr_values, label='Marginal Revenue')
plt.xlabel('Quantity')
plt.ylabel('Cost/Revenue')
plt.title('Marginal Cost and Marginal Revenue')
plt.legend()
plt.show()

# %% [markdown]
# ## 가격 기구
# 자본주의 경제는 자원배분은 가격기구에 의해 이루어진다. 이를 우리는 시장이라고 부르지만 이는 다양하게 존재할 수 있다.
# 가격기구의 작동 매커니즘을 circular flow model과 demand-supply model로 알아보자.
#
# ### circular flow model
# 경제에 정부는 없고 가계와 기업이 존재할때, 이 모형은 가계와 기업의 독립적인 의사결정이 시장을 통해 어떻게 서로 연결되는지에 대해서 보여준다. 가계는 생산요소인 노동을 제공하고 대가를받으며, 기업은 생산물을 생산한기 위해 노동을 수요하며 대가를 지불해야한다. 이에 따라 가계의 의사결정인 노동의 공급과 기업의 의사결정인 노동에 대한 수요는 생산요소시장의 한종류인  노동시장에서 서로 연결되며 가계는 자신이 벌어들인 소득으로 살아간다.
# 소득을 지출해 재화의 구입을 이루며, 기업은 생산무을 판매해 수입을 올린다. 이에따라 기업의 의사결정인 재화의 공급과 가계의 의사결정인 재화에 대한 수요는 생산물 시장을 통해 연결된다.
#
# circular flow model는  현실을 모두 반영하고 있지는 않으나 중요한 부분으로 여겨진다.
# 1. 여러종류의 다양한 기업들이 기업부문 하나로 묶여져 나타나있다.
# 2. 모든 생산이 기업으로만 이루어진다고 간주된다.
# 3. 정부가 포함되지 않고있다.
#
# 위와 같은 한계에도 불구하고 모델의 특성에서 설명한 바와 같이 , circular flow model은 시장기구에 의해 자원배분이 어떻게 이루어질수 있느냐는 문제의 핵심을 명확히 설명해주고 있다.
#
#
#
# ![circular flow model wikipidia](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b8/Circular_flow_of_goods_income.png/720px-Circular_flow_of_goods_income.png)
#
# ### demend-supply model
# 가계와 기업의 독립적인 의사결정은 시장을 통해 연결되나 가계는 기업이 원하는 양만큼 생산요소를 공급하고, 기업은 가계가 원하는 양만큼의 재화를 생산해 과부족이 없게한다. 가격은 수요와 공급이 일치하는 경우에만 안정화 될 수 있다. 가격이 가계와 기업의 의사결정에 어떻게 영향을 주어 자원배분을결정하는지 분석하는 것이 수요 공급 모형이다.
#
# 어떤 재화 X에 대한 수요는 가계에 의해 결정된다. X에 대한 수요에 영향을 주는 요인들로는 X의 가격 $P_x$, 다른 재화의 가격, 가계소득 및 기호등이 있다. 그중에서 X재에 대한 수요량에 가장 직접적으로 영향을주는 요인은 $P_x$ 이다. X재에 대한 수요량에 대해 분석할때,  $P_x$ 이외의 다른 요인들은 일정하다는 가정이 흔히 사용되는데 이를 `ceteris paribus` 의 가정이라고한다.
#
# 아 가정 하에 $P_x$ 가 변화할 때 X 재에 대한 수요량이 어떻게 변화하는지에 대해 나타낸것이 수요곡선 demand curve이다.
#
# 가격이 하락하면 가계는 더많은 양을 수요하기 원하는데 이를 law of demand이다.
# supply curve는 그 반대로 가격이 상승하면 더 많이 공급하기 원한다.
# 이 두 수요와 공급이 균형 즉 equilibrium을 이루면 그 $P_x$ 에서  소비자의 기호가 변화한다거나 혹은 기업의 생산비 조건이 바뀐다거나 하는것과 같은 외부적 충격이 없는 한 계속 유지된다.
# 이는 생산요소시장에도 적용될 수 있다.

# %% [markdown]
# ## 암묵적인 간주
# 수요곡선은 우하향하며, 공급곡선은 우상향하는 것으로 우리는 간주하였다. 이는 소비자선택이론에서는 합리적인 소비자의 선택행위의 결과로 우하향하는 수요곡선이 얻어지게됨을 살펴볼 것이고, 고학년에서는 이를 완화하고 자기만의 이론을 통해 이를 전개볼 수 있게 될 것이다.
#
# 생산자선택이론에서는 기업의 이윤극대화를 이루려하는 의사결정을  통해 우상향하는 공급곡선이 얻어짐을 보며 , 가게와 기업이 항상 확실한 상황에서 의사결정하는 것이 아니므로, uncertainty 가 존재하는 상황에서 가계와 기업의 의사결정이 어떻게 이루어지는지 설명한다.
#
# 기업의 이윤극대화를 위해 어떻게 행동해야 할것인지 시장형태에 따라 다르다.  완전경쟁 독점, 독점적 경쟁 및 과점 시장의 이론으로 자세히 논의된다. 상호의존적인 주제들에서는 현대 이론에서 게임이론을 이해해야 의사결정을 이해할수 있다. 자원배분문제에는 소득분배문제도 포함되며, 생산요소의 수요와 공급에 의해 결정되는데, 이에 대한 자세한 논의는 분배이론에서 진행할 것이다.
#
# 일반균형 및 후생경제학에 대해서는 시장기구에 의해 모든 시장에서 균형을 달성시키는 자원배분을 이루는 것이 가능한지, 이렇게 이뤄진 자원배분이 사회적으로 바람직한 것인지 살펴본다. 시장기구에 의해 효율적인 자원배분을 이루지 못한 시장실패 market failure가 있다. 시장결여와 시장실패에 대해서 살펴보며, 현대 미시경제학의 정보경제학과 이후 논의들을살펴부는 의미를 가져보는 시간이 되면 좋을 것 같다.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy

# %% [markdown]
# 수요와 공급

# %%
def S(q):
    return (q**2)

def D(q):
    return (q - 20)**2

q = np.linspace(0, 16, 1000)

# %%
plt.plot(q, S(q), label = "Supply Curve")
plt.plot(q, D(q), label = "Demand Curve")
plt.title("Supply and Demand")
plt.legend(frameon = False)
plt.xlabel("Quantity $q$")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# 탄력성

# %%
import pandas as pd
data = pd.DataFrame({"Demand": [20, 30, 31, 33, 30, 33, 35], 
                     "Price": [2000, 1800, 1850, 1700, 1800, 1700, 1600]})
print(data)
# Out:
#    Demand  Price
# 0      20   2000
# 1      30   1800
# 2      31   1850
# 3      33   1700
# 4      30   1800
# 5      33   1700
# 6      35   1600

# %%
data["% Change in Demand"] = data["Demand"].pct_change()
data["% Change in Price"] = data["Price"].pct_change()
print(data)
# Out:
#    Demand  Price  % Change in Demand  % Change in Price
# 0      20   2000                 NaN                NaN
# 1      30   1800            0.500000          -0.100000
# 2      31   1850            0.033333           0.027778
# 3      33   1700            0.064516          -0.081081
# 4      30   1800           -0.090909           0.058824
# 5      33   1700            0.100000          -0.055556
# 6      35   1600            0.060606          -0.058824

# %%
data["Price Elasticity"] = data["% Change in Demand"] / data["% Change in Price"]
print(data)
# Out:
#    Demand  Price  % Change in Demand  % Change in Price  Price Elasticity
# 0      20   2000                 NaN                NaN               NaN
# 1      30   1800            0.500000          -0.100000         -5.000000
# 2      31   1850            0.033333           0.027778          1.200000
# 3      33   1700            0.064516          -0.081081         -0.795699
# 4      30   1800           -0.090909           0.058824         -1.545455
# 5      33   1700            0.100000          -0.055556         -1.800000
# 6      35   1600            0.060606          -0.058824         -1.030303

# %% [markdown]
# 소비자 잉여와 생산자 잉여

# %% [markdown]
# 노동시장

# %% [markdown]
# 독점

# %% [markdown]
# 과점
